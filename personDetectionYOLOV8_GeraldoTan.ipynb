# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import yaml

# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="4Pm2DNyY2AupDZxGTS5v")
project = rf.workspace("leo-ueno").project("people-detection-o4rdr")
dataset = project.version(1).download("yolov8")

# %%
model = YOLO("yolov8n.pt")

model.train(
    data="/content/People-Detection-1/data.yaml",
    epochs=50,
    imgsz=640,
    batch=8,
    name="ppe-detection-model",
    pretrained=True
)

# %%
with open("/content/People-Detection-1/data.yaml", "r") as f:
    data = yaml.safe_load(f)

print(data["names"])

# %%
model = YOLO("runs/detect/ppe-detection-model/weights/best.pt")
metrics = model.val()

print(metrics)
